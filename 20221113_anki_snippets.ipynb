# %%
import pandas as pd
import seaborn as sns
sns.set()
from faker import Faker
fake = Faker()
import random
import itertools

# %% [markdown]
# |variable    |class     |description |
# |:-----------|:---------|:-----------|
# |country     |character | Country Name |
# |year        |double    | Year |
# |CL          |double    | Civil Liberties |
# |PR          |double    | Political rights |
# |Status      |character | Status (Free `F`, Not Free `NF`, Partially Free `PF`) |
# |Region_Code |double    | UN Region code |
# |Region_Name |character | UN Region Name |
# |is_ldc      |double    | Is a least developed country (binary 0/1) |

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-02-22/freedom.csv')
df.head()
# Out:
#        country  year  CL  PR Status  Region_Code Region_Name  is_ldc
# 0  Afghanistan  1995   7   7     NF          142        Asia       1
# 1  Afghanistan  1996   7   7     NF          142        Asia       1
# 2  Afghanistan  1997   7   7     NF          142        Asia       1
# 3  Afghanistan  1998   7   7     NF          142        Asia       1
# 4  Afghanistan  1999   7   7     NF          142        Asia       1

# %%
sns.displot(data=df, x="PR")

# %%
sns.lineplot(data=df, x="year", y="PR", hue="Region_Name")
# Out:
# <AxesSubplot:xlabel='year', ylabel='PR'>

# %%
df = sns.load_dataset("penguins")

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(data=df.query("species=='Adelie'"), x="flipper_length_mm")

# %%
sns.displot(data=df, x="flipper_length_mm", hue="species")

# %%
sns.violinplot(data=df, y="flipper_length_mm", x="species")
# Out:
# <AxesSubplot:xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.violinplot(data=df, y="flipper_length_mm", x="species", hue="sex", split=True)
# Out:
# <AxesSubplot:xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.regplot(data=df, y="flipper_length_mm", x="bill_length_mm")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.lmplot(data=df, y="flipper_length_mm", x="bill_length_mm", hue="species")

# %%
sns.lmplot(data=df, y="flipper_length_mm", x="bill_length_mm", row="species")

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.heatmap(df.reset_index().pivot_table(index="sibsp", columns="parch", values="index", aggfunc="count"))
# Out:
# <AxesSubplot:xlabel='parch', ylabel='sibsp'>

# %%
df.reset_index().pivot_table(index="sibsp", columns="parch", values="index", aggfunc="count")
# Out:
# parch      0     1     2    3    4    5    6
# sibsp
# 0      537.0  38.0  29.0  1.0  1.0  2.0  NaN
# 1      123.0  57.0  19.0  3.0  3.0  3.0  1.0
# 2       16.0   7.0   4.0  1.0  NaN  NaN  NaN
# 3        2.0   7.0   7.0  NaN  NaN  NaN  NaN
# 4        NaN   9.0   9.0  NaN  NaN  NaN  NaN
# 5        NaN   NaN   5.0  NaN  NaN  NaN  NaN
# 8        NaN   NaN   7.0  NaN  NaN  NaN  NaN

# %%
g = sns.jointplot(
    data=df,
    x="sibsp", y="parch",# hue="species",
    #kind="kde",
)

# %%
dancers = [(s := random.choice("FM"), fake.name_female() if s == "F" else fake.name_male()) for i in range(10)]
dancers
# Out:
# [('F', 'Stephanie Matthews'),
#  ('F', 'Alisha Aguilar'),
#  ('F', 'Kristin Smith MD'),
#  ('F', 'Hannah Wright'),
#  ('F', 'Victoria Young'),
#  ('M', 'Kyle Romero'),
#  ('M', 'Michael Baker'),
#  ('M', 'Dean Schmidt'),
#  ('F', 'Marissa Singh'),
#  ('F', 'Tracy Bowen')]

# %%
list(itertools.product([d[1] for d in dancers if d[0] == "F"], [d[1] for d in dancers if d[0] == "M"]))
# Out:
# [('Stephanie Matthews', 'Kyle Romero'),
#  ('Stephanie Matthews', 'Michael Baker'),
#  ('Stephanie Matthews', 'Dean Schmidt'),
#  ('Alisha Aguilar', 'Kyle Romero'),
#  ('Alisha Aguilar', 'Michael Baker'),
#  ('Alisha Aguilar', 'Dean Schmidt'),
#  ('Kristin Smith MD', 'Kyle Romero'),
#  ('Kristin Smith MD', 'Michael Baker'),
#  ('Kristin Smith MD', 'Dean Schmidt'),
#  ('Hannah Wright', 'Kyle Romero'),
#  ('Hannah Wright', 'Michael Baker'),
#  ('Hannah Wright', 'Dean Schmidt'),
#  ('Victoria Young', 'Kyle Romero'),
#  ('Victoria Young', 'Michael Baker'),
#  ('Victoria Young', 'Dean Schmidt'),
#  ('Marissa Singh', 'Kyle Romero'),
#  ('Marissa Singh', 'Michael Baker'),
#  ('Marissa Singh', 'Dean Schmidt'),
#  ('Tracy Bowen', 'Kyle Romero'),
#  ('Tracy Bowen', 'Michael Baker'),
#  ('Tracy Bowen', 'Dean Schmidt')]

# %%
list(itertools.combinations(dancers[:5], 3))
# Out:
# [(('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Kristin Smith MD')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Hannah Wright')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Victoria Young')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Kristin Smith MD'),
#   ('F', 'Hannah Wright')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Kristin Smith MD'),
#   ('F', 'Victoria Young')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Hannah Wright'),
#   ('F', 'Victoria Young')),
#  (('F', 'Alisha Aguilar'), ('F', 'Kristin Smith MD'), ('F', 'Hannah Wright')),
#  (('F', 'Alisha Aguilar'), ('F', 'Kristin Smith MD'), ('F', 'Victoria Young')),
#  (('F', 'Alisha Aguilar'), ('F', 'Hannah Wright'), ('F', 'Victoria Young')),
#  (('F', 'Kristin Smith MD'), ('F', 'Hannah Wright'), ('F', 'Victoria Young'))]

# %%
dancers[:5]
# Out:
# [('F', 'Stephanie Matthews'),
#  ('F', 'Alisha Aguilar'),
#  ('F', 'Kristin Smith MD'),
#  ('F', 'Hannah Wright'),
#  ('F', 'Victoria Young')]

# %%
list(itertools.permutations(dancers[:5], 3))
# Out:
# [(('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Kristin Smith MD')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Hannah Wright')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Victoria Young')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Kristin Smith MD'),
#   ('F', 'Alisha Aguilar')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Kristin Smith MD'),
#   ('F', 'Hannah Wright')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Kristin Smith MD'),
#   ('F', 'Victoria Young')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Hannah Wright'),
#   ('F', 'Alisha Aguilar')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Hannah Wright'),
#   ('F', 'Kristin Smith MD')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Hannah Wright'),
#   ('F', 'Victoria Young')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Victoria Young'),
#   ('F', 'Alisha Aguilar')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Victoria Young'),
# ...

# %%
list(itertools.combinations_with_replacement(dancers[:5], 3))
# Out:
# [(('F', 'Stephanie Matthews'),
#   ('F', 'Stephanie Matthews'),
#   ('F', 'Stephanie Matthews')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Stephanie Matthews'),
#   ('F', 'Kristin Smith MD')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Stephanie Matthews'),
#   ('F', 'Hannah Wright')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Stephanie Matthews'),
#   ('F', 'Victoria Young')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Alisha Aguilar')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Kristin Smith MD')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Hannah Wright')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Alisha Aguilar'),
#   ('F', 'Victoria Young')),
#  (('F', 'Stephanie Matthews'),
#   ('F', 'Kristin Smith MD'),
#   ('F', 'Kristin Smith MD')),
#  (('F', 'Stephanie Matthews'),
# ...

# %%
df = pd.read_csv("ElectricCarData_Clean.csv")
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...
